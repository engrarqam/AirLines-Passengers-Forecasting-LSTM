# %% [markdown]
# ### Airlines Passenger Forecasting using Stacked LSTM

# %% [markdown]
# This is a problem where, given a year and a month, the task is to predict the number of international airline passengers in units of 1,000. The data ranges from January 1949 to December 1960, or 12 years, with 144 observations.

# %%
#kaggle dataset
#https://www.kaggle.com/rakannimer/air-passengers?select=AirPassengers.csv

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Code to read csv file into colaboratory:

#3.1 Read file as panda dataframe
import pandas as pd
df=pd.read_csv('/content/drive/MyDrive/Complete Projects/AirLines-Passengers-Forecasting-LSTM-master/AirPassengers.csv')

# %%
df.head()
# Out:
#      Month  #Passengers
# 0  1949-01          112
# 1  1949-02          118
# 2  1949-03          132
# 3  1949-04          129
# 4  1949-05          121

# %%
df.tail()
# Out:
#        Month  #Passengers
# 139  1960-08          606
# 140  1960-09          508
# 141  1960-10          461
# 142  1960-11          390
# 143  1960-12          432

# %%
import matplotlib.pyplot as plt

# %%
plt.plot(df.iloc[:,1])

# %% [markdown]
# ### Scaling
# LSTMs are sensitive to the scale of the input data, specifically when the sigmoid (default) or tanh activation functions are used. It can be a good practice to rescale the data to the range of 0-to-1, also called normalizing. We can easily normalize the dataset using the MinMaxScaler preprocessing class from the scikit-learn library.

# %%
from sklearn.preprocessing import MinMaxScaler

# %%
df.iloc[:,1]
# Out:
# 0      112
# 1      118
# 2      132
# 3      129
# 4      121
#       ...
# 139    606
# 140    508
# 141    461
# 142    390
# 143    432
# Name: #Passengers, Length: 144, dtype: int64

# %%
scaler=MinMaxScaler(feature_range=(0,1))
df=scaler.fit_transform(df.iloc[:,1:])

# %%
df.shape
# Out:
# (144, 1)

# %%
df
# Out:
# array([[0.01544402],
#        [0.02702703],
#        [0.05405405],
#        [0.04826255],
#        [0.03281853],
#        [0.05984556],
#        [0.08494208],
#        [0.08494208],
#        [0.06177606],
#        [0.02895753],
#        [0.        ],
#        [0.02702703],
#        [0.02123552],
#        [0.04247104],
#        [0.07142857],
#        [0.05984556],
#        [0.04054054],
#        [0.08687259],
#        [0.12741313],
#        [0.12741313],
#        [0.1042471 ],
#        [0.05598456],
#        [0.01930502],
#        [0.06949807],
#        [0.07915058],
#        [0.08880309],
#        [0.14285714],
#        [0.11389961],
#        [0.13127413],
#        [0.14285714],
#        [0.18339768],
#        [0.18339768],
#        [0.15444015],
#        [0.11196911],
#        [0.08108108],
#        [0.11969112],
#        [0.12934363],
#        [0.14671815],
#        [0.17181467],
#        [0.14864865],
#        [0.15250965],
#        [0.22007722],
#        [0.24324324],
#        [0.26640927],
#        [0.2027027 ],
#        [0.16795367],
#        [0.13127413],
#        [0.17374517],
#        [0.17760618],
#        [0.17760618],
#        [0.25482625],
#        [0.25289575],
#        [0.24131274],
#        [0.26833977],
#        [0.30888031],
#        [0.32432432],
#        [0.25675676],
#        [0.20656371],
#        [0.14671815],
#        [0.18725869],
#        [0.19305019],
#        [0.16216216],
#        [0.25289575],
#        [0.23745174],
#        [0.25096525],
#        [0.30888031],
#        [0.38223938],
#        [0.36486486],
#        [0.2992278 ],
#        [0.24131274],
#        [0.19111969],
#        [0.24131274],
#        [0.26640927],
#        [0.24903475],
#        [0.31467181],
#        [0.31853282],
#        [0.32046332],
#        [0.40733591],
#        [0.5019305 ],
#        [0.46911197],
#        [0.4015444 ],
#        [0.32818533],
#        [0.25675676],
#        [0.33590734],
#        [0.34749035],
#        [0.33397683],
#        [0.41119691],
#        [0.4034749 ],
#        [0.41312741],
#        [0.52123552],
#        [0.5965251 ],
#        [0.58108108],
#        [0.48455598],
#        [0.38996139],
#        [0.32239382],
#        [0.38996139],
#        [0.40733591],
#        [0.38030888],
#        [0.48648649],
#        [0.47104247],
#        [0.48455598],
#        [0.61389961],
#        [0.6969112 ],
#        [0.7007722 ],
#        [0.57915058],
#        [0.46911197],
#        [0.38803089],
#        [0.44787645],
#        [0.45559846],
#        [0.41312741],
#        [0.4980695 ],
#        [0.47104247],
#        [0.5       ],
#        [0.63899614],
#        [0.74710425],
#        [0.77413127],
#        [0.57915058],
#        [0.49227799],
#        [0.3976834 ],
#        [0.44980695],
#        [0.49420849],
#        [0.45945946],
#        [0.58301158],
#        [0.56370656],
#        [0.61003861],
#        [0.71042471],
#        [0.85714286],
#        [0.87837838],
#        [0.69305019],
#        [0.58494208],
#        [0.4980695 ],
#        [0.58108108],
#        [0.6042471 ],
#        [0.55405405],
#        [0.60810811],
#        [0.68918919],
#        [0.71042471],
#        [0.83204633],
#        [1.        ],
#        [0.96911197],
#        [0.77992278],
#        [0.68918919],
#        [0.55212355],
#        [0.63320463]])

# %%
##splitting dataset into train and test split
training_size=int(len(df)*0.65)

# %%
training_size
# Out:
# 93

# %%
test_size=len(df)-training_size

# %%
test_size
# Out:
# 51

# %%
train_data,test_data=df[0:training_size,:],df[training_size:len(df),:1]

# %%
test_data
# Out:
# array([[0.38996139],
#        [0.32239382],
#        [0.38996139],
#        [0.40733591],
#        [0.38030888],
#        [0.48648649],
#        [0.47104247],
#        [0.48455598],
#        [0.61389961],
#        [0.6969112 ],
#        [0.7007722 ],
#        [0.57915058],
#        [0.46911197],
#        [0.38803089],
#        [0.44787645],
#        [0.45559846],
#        [0.41312741],
#        [0.4980695 ],
#        [0.47104247],
#        [0.5       ],
#        [0.63899614],
#        [0.74710425],
#        [0.77413127],
#        [0.57915058],
#        [0.49227799],
#        [0.3976834 ],
#        [0.44980695],
#        [0.49420849],
#        [0.45945946],
#        [0.58301158],
#        [0.56370656],
#        [0.61003861],
#        [0.71042471],
#        [0.85714286],
#        [0.87837838],
#        [0.69305019],
#        [0.58494208],
#        [0.4980695 ],
#        [0.58108108],
#        [0.6042471 ],
#        [0.55405405],
#        [0.60810811],
#        [0.68918919],
#        [0.71042471],
#        [0.83204633],
#        [1.        ],
#        [0.96911197],
#        [0.77992278],
#        [0.68918919],
#        [0.55212355],
#        [0.63320463]])

# %%
import numpy
# convert an array of values into a dataset matrix
def create_dataset(dataset, time_step=1):
	dataX, dataY = [], []
	for i in range(len(dataset)-time_step-1):
		a = dataset[i:(i+time_step), 0]   ###i=0, 0,1,2,3
		dataX.append(a)
		dataY.append(dataset[i + time_step, 0])
	return numpy.array(dataX), numpy.array(dataY)

# %%
# reshape into X=t,t+1,t+2,t+3 and Y=t+4
time_step = 4
X_train, y_train = create_dataset(train_data, time_step)
X_test, ytest = create_dataset(test_data, time_step)

# %%
X_train.shape, y_train.shape
# Out:
# ((88, 4), (88,))

# %%
import numpy as np
# reshape input to be [samples, time steps, features] which is required for LSTM
X_train =X_train.reshape(X_train.shape[0], 4, 1)
X_test = X_test.reshape(X_test.shape[0], 4, 1)

# %%
X_train.shape
# Out:
# (88, 4, 1)

# %%
### Create the LSTM model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
from tensorflow.keras.layers import LSTM

# %%
model=Sequential()
model.add(LSTM(50,return_sequences=True,input_shape=(4,1)))
model.add(LSTM(50))
model.add(Dense(1))
model.compile(loss='mean_squared_error',optimizer='adam')
model.fit(X_train,y_train,validation_data=(X_test,ytest),epochs=100,batch_size=1,verbose=1)
# Out:
# Epoch 1/100
# 88/88 [==============================] - 4s 13ms/step - loss: 0.0115 - val_loss: 0.0419
# Epoch 2/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0069 - val_loss: 0.0294
# Epoch 3/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0062 - val_loss: 0.0313
# Epoch 4/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0056 - val_loss: 0.0308
# Epoch 5/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0049 - val_loss: 0.0305
# Epoch 6/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0052 - val_loss: 0.0281
# Epoch 7/100
# 88/88 [==============================] - 0s 6ms/step - loss: 0.0049 - val_loss: 0.0362
# Epoch 8/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0049 - val_loss: 0.0240
# Epoch 9/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0053 - val_loss: 0.0261
# Epoch 10/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0046 - val_loss: 0.0451
# Epoch 11/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0.0051 - val_loss: 0.0202
# Epoch 12/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0040 - val_loss: 0.0238
# Epoch 13/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0043 - val_loss: 0.0189
# Epoch 14/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0052 - val_loss: 0.0174
# Epoch 15/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0035 - val_loss: 0.0196
# Epoch 16/100
# 88/88 [==============================] - 1s 6ms/step - loss: 0.0035 - val_loss: 0.0152
# Epoch 17/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0047 - val_loss: 0.0132
# Epoch 18/100
# 88/88 [==============================] - 1s 6ms/step - loss: 0.0033 - val_loss: 0.0096
# Epoch 19/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0033 - val_loss: 0.0117
# Epoch 20/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0028 - val_loss: 0.0081
# Epoch 21/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0025 - val_loss: 0.0089
# Epoch 22/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0028 - val_loss: 0.0079
# Epoch 23/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0022 - val_loss: 0.0084
# Epoch 24/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0022 - val_loss: 0.0091
# Epoch 25/100
# 88/88 [==============================] - 0s 4ms/step - loss: 0
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0170
# Epoch 93/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0116
# Epoch 94/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.0148
# Epoch 95/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0022 - val_loss: 0.0098
# Epoch 96/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0020 - val_loss: 0.0107
# Epoch 97/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.0094
# Epoch 98/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.0132
# Epoch 99/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0019 - val_loss: 0.0258
# Epoch 100/100
# 88/88 [==============================] - 0s 5ms/step - loss: 0.0018 - val_loss: 0.0109

# %%
### Lets Do the prediction and check performance metrics
train_predict=model.predict(X_train)
test_predict=model.predict(X_test)

# %%
test_predict
# Out:
# array([[0.39138755],
#        [0.36539224],
#        [0.5441587 ],
#        [0.41041812],
#        [0.49879968],
#        [0.6724713 ],
#        [0.65641356],
#        [0.6267164 ],
#        [0.4310498 ],
#        [0.40779176],
#        [0.33678022],
#        [0.48270446],
#        [0.42149863],
#        [0.38644207],
#        [0.5504636 ],
#        [0.4027262 ],
#        [0.5249527 ],
#        [0.6958371 ],
#        [0.71873844],
#        [0.6903541 ],
#        [0.33637154],
#        [0.49213764],
#        [0.2987559 ],
#        [0.48728502],
#        [0.47865704],
#        [0.4155975 ],
#        [0.6655044 ],
#        [0.4522971 ],
#        [0.6493808 ],
#        [0.70860696],
#        [0.8635307 ],
#        [0.6782747 ],
#        [0.4156396 ],
#        [0.5184492 ],
#        [0.34690648],
#        [0.617314  ],
#        [0.5176819 ],
#        [0.48563755],
#        [0.6410777 ],
#        [0.6566999 ],
#        [0.6234709 ],
#        [0.88079727],
#        [0.93073386],
#        [0.5903391 ],
#        [0.4945093 ],
#        [0.53062797]], dtype=float32)

# %%
##Transformback to original form
train_predict=scaler.inverse_transform(train_predict)
test_predict=scaler.inverse_transform(test_predict)

# %%
test_predict
# Out:
# array([[306.73874],
#        [293.27316],
#        [385.8742 ],
#        [316.5966 ],
#        [362.37823],
#        [452.34015],
#        [444.02225],
#        [428.6391 ],
#        [327.28378],
#        [315.23615],
#        [278.45215],
#        [354.04092],
#        [322.33627],
#        [304.177  ],
#        [389.14017],
#        [312.61218],
#        [375.9255 ],
#        [464.44363],
#        [476.30652],
#        [461.60345],
#        [278.24048],
#        [358.9273 ],
#        [258.75555],
#        [356.41367],
#        [351.94434],
#        [319.2795 ],
#        [448.7313 ],
#        [338.28992],
#        [440.37927],
#        [471.0584 ],
#        [551.3089 ],
#        [455.3463 ],
#        [319.3013 ],
#        [372.5567 ],
#        [283.69757],
#        [423.76865],
#        [372.15924],
#        [355.56027],
#        [436.07825],
#        [444.17056],
#        [426.95795],
#        [560.253  ],
#        [586.1202 ],
#        [409.7957 ],
#        [360.15582],
#        [378.8653 ]], dtype=float32)

# %%
y_train.shape,train_predict.shape,train_predict
# Out:
# ((88,), (88, 1), array([[131.55104 ],
#         [125.84802 ],
#         [138.49358 ],
#         [149.66035 ],
#         [150.09421 ],
#         [140.64818 ],
#         [126.43817 ],
#         [112.80892 ],
#         [122.32525 ],
#         [118.515686],
#         [128.11462 ],
#         [142.20554 ],
#         [137.51968 ],
#         [130.3244  ],
#         [152.2463  ],
#         [170.774   ],
#         [170.81769 ],
#         [161.77538 ],
#         [140.13588 ],
#         [123.72762 ],
#         [144.40991 ],
#         [146.5058  ],
#         [152.15054 ],
#         [180.54842 ],
#         [163.79272 ],
#         [177.1274  ],
#         [181.77205 ],
#         [203.10446 ],
#         [200.19553 ],
#         [186.69006 ],
#         [167.75719 ],
#         [154.0198  ],
#         [172.38454 ],
#         [173.40169 ],
#         [183.02484 ],
#         [196.47221 ],
#         [182.70395 ],
#         [188.5969  ],
#         [225.13498 ],
#         [230.52837 ],
#         [245.4251  ],
#         [204.63455 ],
#         [198.04527 ],
#         [178.4018  ],
#         [202.35718 ],
#         [197.98984 ],
#         [199.35426 ],
#         [245.03282 ],
#         [232.14561 ],
#         [231.2764  ],
#         [250.38878 ],
#         [269.76828 ],
#         [272.63513 ],
#         [228.58315 ],
#         [215.90126 ],
#         [184.98868 ],
#         [211.84981 ],
#         [206.32423 ],
#         [189.98558 ],
#         [246.80214 ],
#         [222.36058 ],
#         [239.71747 ],
#         [273.11697 ],
#         [310.5352  ],
#         [281.66055 ],
#         [252.03787 ],
#         [230.46164 ],
#         [207.11806 ],
#         [241.39282 ],
#         [244.26842 ],
#         [232.18384 ],
#         [279.95346 ],
#         [265.10916 ],
#         [272.5268  ],
#         [332.7973  ],
#         [374.0403  ],
#         [317.97665 ],
#         [300.60577 ],
#         [263.98227 ],
#         [233.76112 ],
#         [299.2095  ],
#         [278.11444 ],
#         [275.6606  ],
#         [335.29794 ],
#         [298.34564 ],
#         [322.53955 ],
#         [398.57214 ],
#         [406.79184 ]], dtype=float32))

# %%
### Calculate RMSE performance metrics
import math
from sklearn.metrics import mean_squared_error
math.sqrt(mean_squared_error(y_train,train_predict))
# Out:
# 223.12493856746153

# %%
### Test Data RMSE
math.sqrt(mean_squared_error(ytest,test_predict))
# Out:
# 392.28559436228886

# %%
### Plotting 
# shift train predictions for plotting
lookback=4
trainPredictPlot = numpy.empty_like(df)
trainPredictPlot[:, :] = np.nan
trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict

# shift test predictions for plotting
testPredictPlot = numpy.empty_like(df)
testPredictPlot[:, :] = numpy.nan
testPredictPlot[len(train_predict)+(look_back*2)+1:len(df)-1, :] = test_predict

# plot baseline and predictions
plt.plot(scaler.inverse_transform(df))
plt.plot(trainPredictPlot)
plt.plot(testPredictPlot)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-34-3ca93b619e70> in <module>()
#       4 trainPredictPlot = numpy.empty_like(df)
#       5 trainPredictPlot[:, :] = np.nan
# ----> 6 trainPredictPlot[look_back:len(train_predict)+look_back, :] = train_predict
#       7
#       8 # shift test predictions for plotting
#
# NameError: name 'look_back' is not defined
